# %%
DIGITS = '0123456789abcdef'
def convertToBase(number):
    i=2
    origin=number
    while i<17:
        number = origin
        base=i
        remainders = []
        while number > 0:
            remainder = number % base
            remainders.append(remainder)
            number = number // base
        converted = []
        while remainders:
            converted.append(DIGITS[remainders.pop()])
        print("Converted "+str(origin)+" into base "+str(base)+" : "+''.join(converted)) 
        if i==2: i=8 # switch base from 2 to 8
        elif i==8: i=16 # switch base from 8 to 16
        else: i=20 3 # switch base from 16 to 20 , so we'll be out of the while loop
convertToBase(230) # enter a number

# for each base, save the reminders of dividing again and again the number by the base.
# for each reminder in 'reminders' save it's value from 0 to f by using 'DIGITS' , and add it to 'converted'.
# print 'converted' and move to the next base.
# Out:
#   File "<ipython-input-3-b2a49fae1807>", line 19
#     else: i=20 3 # switch base from 16 to 20 , so we'll be out of the while loop
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\talia\Downloads/cast.csv')
df
# Out:
#                                      title  year                         name  \
# 0                          Suuri illusioni  1985                       Homo $
# 1           Gangsta Rap: The Glockumentary  2007                    Too $hort
# 2                        Menace II Society  1993                    Too $hort
# 3        Porndogs: The Adventures of Sadie  2009                    Too $hort
# 4                       Stop Pepper Palmer  2014                    Too $hort
# ...                                    ...   ...                          ...
# 3333690                     Stuttur Frakki  1993    Sveinbj?rg ??rhallsd?ttir
# 3333691                            Foxtrot  1988            Lilja ??risd?ttir
# 3333692   Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3333693                       U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3333694                  Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
#             type               character     n
# 0          actor                  Guests  22.0
# 1          actor                 Himself   NaN
# 2          actor                 Lew-Loc  27.0
# 3          actor                   Bosco   3.0
# 4          actor                 Himself   NaN
# ...          ...                     ...   ...
# 3333690  actress              Flugfreyja  24.0
# 3333691  actress                    D?ra  24.0
# 3333692  actress            Woman in Bus  26.0
# 3333693  actress  Afgr.dama ? bens?nst??  17.0
# 3333694  actress       Pensionatv?rtinde   NaN
#
# [3333695 rows x 6 columns]

# %%
import numpy as np

# %% [markdown]
# Question 1
#
# How many movies have the title "Hamlet"?

# %%
h = df.query("title == 'Hamlet'")
hamlet = h.drop_duplicates(subset=['year'])
print("There are " , (df.title == 'Hamlet').sum() , " movies with the title 'Hamlet'.\nOnly" , hamlet.shape[0] , "are from different years.")
# Out:
# There are  299  movies with the title 'Hamlet'.
# Only 17 are from different years.

# %% [markdown]
# Question 2
#
# List all of the "Treasure Island" movies from earliest to most recent.

# %%
tIsland = (df.query("title == 'Treasure Island'")).sort_values('year')
tIslandClean = (tIsland.drop_duplicates(subset=['year'])).drop(columns=['name' , 'type' , 'character' , 'n'])
(tIslandClean.reset_index()).drop(columns='index')
# Out:
#              title  year
# 0  Treasure Island  1918
# 1  Treasure Island  1920
# 2  Treasure Island  1934
# 3  Treasure Island  1950
# 4  Treasure Island  1972
# 5  Treasure Island  1973
# 6  Treasure Island  1985
# 7  Treasure Island  1999

# %% [markdown]
# Question 3
#
# How many roles were credited in the silent 1921 version of Hamlet?

# %%
print(len(df[(df.title == "Hamlet") & (df.year == 1921)]) , "roles were credited in the silent 1921 version of Hamlet.")
# Out:
# 9 roles were credited in the silent 1921 version of Hamlet.

# %%
#3
Hamlet= df1[df1['title']=="Hamlet"]

# %%
Hamlet
# Out:
#           title  year              name     type              character     n
# 1456     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 6710     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 10274    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 10275    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 12743    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# 3212647  Hamlet  1964      Carol Teitel  actress                   Lady   NaN
# 3236803  Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# 3257437  Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# 3284728  Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# 3304265  Hamlet  1996      Kate Winslet  actress                Ophelia  46.0
#
# [299 rows x 6 columns]

# %%
Hamlet1921= Hamlet[Hamlet['year']==1921]

# %%
Hamlet1921
# Out:
#           title  year                    name     type         character    n
# 6710     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 408456   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 495468   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1015046  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 1948795  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2116906  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2370048  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2713980  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 2964897  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %% [markdown]
# Question 4
#
# Use groupby() to plot the number of "Hamlet" films made each decade.

# %%
hamlet.groupby(hamlet.year // 10 * 10).size().plot(kind='bar' , color='darkturquoise' , title='Number of "Hamlet" Films Made Each Decade')
# Out:
# <AxesSubplot:title={'center':'Number of "Hamlet" Films Made Each Decade'}, xlabel='year'>

# %%
#4
Hamlet= df1[df1['title']=="Hamlet"]

# %%
Hamlet_num=Hamlet.groupby('year').year.count()

# %%
Hamlet_num
# Out:
# year
# 1910     1
# 1911     6
# 1913    21
# 1921     9
# 1948    25
# 1954     1
# 1964    33
# 1969    24
# 1973     8
# 1976    11
# 1987     3
# 1990    29
# 1996    55
# 2000    38
# 2009    17
# 2011    12
# 2015     6
# Name: year, dtype: int64

# %%
#לחלק לפי עשור

# %% [markdown]
# Question 5
#
# How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
byYearsIn1950 = df
byYearsIn1950 = byYearsIn1950[byYearsIn1950.year // 10 == 195]
byYearsIn1950 = byYearsIn1950[byYearsIn1950.n == 1]
byYearsIn1950.groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      604
#       actress    271
# 1951  actor      633
#       actress    272
# 1952  actor      591
#       actress    284
# 1953  actor      634
#       actress    290
# 1954  actor      626
#       actress    298
# 1955  actor      606
#       actress    264
# 1956  actor      614
#       actress    288
# 1957  actor      708
#       actress    284
# 1958  actor      694
#       actress    275
# 1959  actor      678
#       actress    287
# dtype: int64

# %%
#5
a1950= df1[df1['year']==1950]
a1950
# Out:
#                                              title  year              name  \
# 229                               Palletoori Pilla  1950    Subba Rao A.V.
# 370                                   Hallin Janne  1950    Kosti Aaltonen
# 371                                   Hallin Janne  1950    Kosti Aaltonen
# 1338                     Fortunes of Captain Blood  1950    Abdullah Abbas
# 1689     Abbott and Costello in the Foreign Legion  1950        Bud Abbott
# ...                                            ...   ...               ...
# 3333034                               El desalmado  1950     Dalia ??iguez
# 3333041                           La vida en broma  1950     Dalia ??iguez
# 3333046                               Quinto patio  1950     Dalia ??iguez
# 3333369                       Anderssonskans Kalle  1950  Ingrid ?stergren
# 3333630                         Akdeniz korsanlari  1950   Muazzez ?lkerer
#
#             type                          character    n
# 229        actor                      Kampanna Dora  4.0
# 370        actor                              Rosvo  NaN
# 371        actor                            Vartija  NaN
# 1338       actor                        Crew Member  NaN
# 1689       actor                          Bud Jones  1.0
# ...          ...                                ...  ...
# 3333034  actress         Do?a Mar?a, madre de Vidal  4.0
# 3333041  actress                        Rebeca Mata  4.0
# 3333046  actress  Do?a Blanquita Z??iga de Vallarta  5.0
# 3333369  actress                Summer Camp Manager  NaN
# 3333630  actress                              Maria  2.0
#
# [21499 rows x 6 columns]

# %% [markdown]
# Question 6
#
# List the 10 actors/actresses that have the most leading roles (n=1) since the 1990's.

# %%
since1990 = df
since1990 = since1990[since1990.year >= 1990]
since1990 = since1990[since1990.n == 1]
((since1990.groupby(['name']).size()).sort_values(ascending=False)).head(10)
# Out:
# name
# Mohanlal              126
# Mammootty             118
# Akshay Kumar           87
# Jayaram                76
# Andy Lau               72
# Ajay Devgn             69
# Eric Roberts           68
# Amitabh Bachchan       68
# Nagarjuna Akkineni     60
# Dilip                  59
# dtype: int64

# %%
#6
since1990= df1[df1['year']>=1990]

# %%
since1990_leading= since1990 [since1990['n']==1.0]

# %%
since1990_leading
# Out:
#                           title  year              name     type  \
# 88       Live Freaky Die Freaky  2006           Nick 13    actor
# 125       All Things Fall Apart  2011           50 Cent    actor
# 130                 Freelancers  2012           50 Cent    actor
# 131      Get Rich or Die Tryin'  2005           50 Cent    actor
# 132                         Gun  2010           50 Cent    actor
# ...                         ...   ...               ...      ...
# 3333400                     120  2008       ?zge ?zberk  actress
# 3333513                Doyumsuz  1990       Bahar ?ztan  actress
# 3333522                  Kadife  2012      Ayta? ?ztuna  actress
# 3333556              Dig og mig  2008  Julie R. ?lgaard  actress
# 3333576      Mimi og madammerne  1998         Tammi ?st  actress
#
#               character    n
# 88       TV Reporter #1  1.0
# 125                Deon  1.0
# 130                Malo  1.0
# 131              Marcus  1.0
# 132                Rich  1.0
# ...                 ...  ...
# 3333400          M?nire  1.0
# 3333513           Bahar  1.0
# 3333522      Kadife Ana  1.0
# 3333556       Stephanie  1.0
# 3333576            Mimi  1.0
#
# [64586 rows x 6 columns]

# %%
character_lednum=since1990_leading.groupby('character').character.count()

# %% [markdown]
# Question 7
#
# List, in order by year, each of the films in which Frank Oz has played more than 1 role

# %%
frank = df
frank = frank[frank.name == 'Frank Oz']
frank.sort_values('year')
rolesAmount = frank.groupby(['year','title']).size()
rolesAmount[rolesAmount>1]
# Out:
# year  title
# 1979  The Muppet Movie                            8
# 1981  An American Werewolf in London              2
#       The Great Muppet Caper                      6
# 1982  The Dark Crystal                            2
# 1984  The Muppets Take Manhattan                  7
# 1985  Sesame Street Presents: Follow that Bird    3
# 1992  The Muppet Christmas Carol                  7
# 1996  Muppet Treasure Island                      4
# 1999  Muppets from Space                          4
#       The Adventures of Elmo in Grouchland        3
# dtype: int64
